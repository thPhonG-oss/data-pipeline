# %%
"""
symbol: mã cổ phiếu cần tra cứu.
period: Kỳ báo cáo. year cho báo cáo năm và quarter cho báo cáo quý. Mặc định là quarter để áp dụng cho tất cả các thao tác truy xuất tiếp theo. Đổi thông số mới tại từng phương thức cụ thể nếu muốn.
show_log: mặc định là False giúp tắt các thông tin log thể hiện quá trình thực thi lệnh.
"""
from vnstock_data import Finance

# Khởi tạo đối tượng
fin = Finance(symbol='HPG', period='year', source='vci')
fin1 = Finance(symbol='HPG', period='quarter', source='vci')

# %%
# Bảng cân đối kế toán
"""
- period: Kỳ báo cáo. year cho báo cáo năm và quarter cho báo cáo quý. Mặc định là None để nhận thông tin period khi khởi tạo đối tượng, bạn đổi nếu muốn.
- lang: Ngôn ngữ hiển thị dữ liệu. Mặc định là en cho tiếng Anh, đổi thành vi cho tiếng Việt
- mode (str): Chế độ trả về dữ liệu. Mặc định là 'final' cho dữ liệu đã qua xử lý tên, nếu mode='raw' thì trả về DataFrame dữ liệu thô cho lưu trữ cơ sở dữ liệu.
- style (str): Chế độ hiển thị tên cột. Mặc định là 'readable' cho tên hiển thị, hoặc 'code' cho tên mã dạng snake_case không dấu phù hợp lưu trữ cho cơ sở dữ liệu.
- get_all (bool): Có lấy tất cả các cột hay không. Mặc định là False để lấy chỉ các cột quan trọng đã tinh chỉnh.
"""
fin.balance_sheet(lang='vi').to_csv("balance_sheet_year.csv", index=False, encoding='utf-8-sig')
fin1.balance_sheet(lang='vi').to_csv("balance_sheet_quarter.csv", index=False, encoding='utf-8-sig')

# %%
# Báo cáo kết quả kinh doanh
"""
- period: Kỳ báo cáo. year cho báo cáo năm và quarter cho báo cáo quý. Mặc định là None để nhận thông tin period khi khởi tạo đối tượng, bạn đổi nếu muốn.
- lang: Ngôn ngữ hiển thị dữ liệu. Mặc định là en cho tiếng Anh, đổi thành vi cho tiếng Việt
- mode (str): Chế độ trả về dữ liệu. Mặc định là 'final' cho dữ liệu đã qua xử lý tên, nếu mode='raw' thì trả về DataFrame dữ liệu thô cho lưu trữ cơ sở dữ liệu.
- style (str): Chế độ hiển thị tên cột. Mặc định là 'readable' cho tên hiển thị, hoặc 'code' cho tên mã dạng snake_case không dấu phù hợp lưu trữ cho cơ sở dữ liệu.
- get_all (bool): Có lấy tất cả các cột hay không. Mặc định là False để lấy chỉ các cột quan trọng đã tinh chỉnh.
"""
fin.income_statement(lang='vi').to_csv("income_statement_year.csv", index=False, encoding='utf-8-sig')
fin1.income_statement(lang='vi').to_csv("income_statement_quarter.csv", index=False, encoding='utf-8-sig')

# %%
# Báo cáo lưu chuyển tiền tệ
"""
- period: Kỳ báo cáo. year cho báo cáo năm và quarter cho báo cáo quý. Mặc định là None để nhận thông tin period khi khởi tạo đối tượng, bạn đổi nếu muốn.
- lang: Ngôn ngữ hiển thị dữ liệu. Mặc định là en cho tiếng Anh, đổi thành vi cho tiếng Việt
- mode (str): Chế độ trả về dữ liệu. Mặc định là 'final' cho dữ liệu đã qua xử lý tên, nếu mode='raw' thì trả về DataFrame dữ liệu thô cho lưu trữ cơ sở dữ liệu.
- style (str): Chế độ hiển thị tên cột. Mặc định là 'readable' cho tên hiển thị, hoặc 'code' cho tên mã dạng snake_case không dấu phù hợp lưu trữ cho cơ sở dữ liệu.
- get_all (bool): Có lấy tất cả các cột hay không. Mặc định là False để lấy chỉ các cột quan trọng đã tinh chỉnh.
"""
fin.cash_flow(lang='vi').to_csv("cash_flow_year.csv", index=False, encoding='utf-8-sig')
fin1.cash_flow(lang='vi').to_csv("cash_flow_quarter.csv", index=False, encoding='utf-8-sig')

# %%
# Chỉ số tài chính
"""
- period: Kỳ báo cáo. year cho báo cáo năm và quarter cho báo cáo quý. Mặc định là None để nhận thông tin period khi khởi tạo đối tượng, bạn đổi nếu muốn.
- lang: Ngôn ngữ hiển thị dữ liệu. Mặc định là en cho tiếng Anh, đổi thành vi cho tiếng Việt
- mode (str): Chế độ trả về dữ liệu. Mặc định là 'final' cho dữ liệu đã qua xử lý tên, nếu mode='raw' thì trả về DataFrame dữ liệu thô cho lưu trữ cơ sở dữ liệu.
- style (str): Chế độ hiển thị tên cột. Mặc định là 'readable' cho tên hiển thị, hoặc 'code' cho tên mã dạng snake_case không dấu phù hợp lưu trữ cho cơ sở dữ liệu.
- get_all (bool): Có lấy tất cả các cột hay không. Mặc định là False để lấy chỉ các cột quan trọng đã tinh chỉnh.
"""
fin.ratio(lang='vi').to_csv("ratio_year.csv", index=False, encoding='utf-8-sig')
fin1.ratio(lang='vi').to_csv("ratio_quarter.csv", index=False, encoding='utf-8-sig')

# %%
# Thuyết minh báo cáo tài chính
"""
period (str): Kỳ báo cáo tài chính. Mặc định là None.
lang (str): Ngôn ngữ của báo cáo. Mặc định là 'en'.
mode (str): Chế độ trả về dữ liệu. Mặc định là 'final' cho dữ liệu đã qua xử lý tên, nếu mode='raw' thì trả về DataFrame dữ liệu thô cho lưu trữ cơ sở dữ liệu.
style (str): Chế độ hiển thị tên cột. Mặc định là 'readable' cho tên hiển thị, hoặc 'code' cho tên mã dạng snake_case không dấu phù hợp lưu trữ cho cơ sở dữ liệu.
get_all (bool): Có lấy tất cả các cột hay không. Mặc định là False để lấy chỉ các cột quan trọng đã tinh chỉnh.
"""
fin.note(lang='vi').to_csv("note_year.csv", index=False, encoding='utf-8-sig')
fin1.note(lang='vi').to_csv("note_quarter.csv", index=False, encoding='utf-8-sig')
