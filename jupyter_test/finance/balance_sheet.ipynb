# %%
from vnstock_data import Finance

# Khởi tạo đối tượng
fin = Finance(symbol='HPG', period='year', source='vci')
fin1 = Finance(symbol='AAA', period='quarter', source='vci')

# %%
fin1.balance_sheet(lang='vi', mode='raw', style='readable', get_all=True).to_csv('balance_sheet_raw.csv', index=False, encoding='utf-8-sig')
