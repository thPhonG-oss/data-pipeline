# %%
from vnstock_data import Listing

listing = Listing(source='vnd')

listing.all_symbols().to_csv('all_symbols.csv', index=False, encoding='utf-8-sig')

# %%
list = Listing(source='vci')
list.industries_icb().to_csv('industries_icb.csv', index=False, encoding='utf-8-sig')

# %%
from vnstock_data import Reference

ref = Reference()

# Tất cả symbol
all_symbols = ref.equity.list()

# Cổ phiếu nhóm VN30
vn30 = ref.equity.list_by_group("VN30")

# Cổ phiếu sàn HSX
hsx_stocks = ref.equity.list_by_exchange("HSX")

# Cổ phiếu theo ngành ICB
industry_stocks = ref.equity.list_by_industry()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 12
#       9 vn30 = ref.equity.list_by_group("VN30")
#      11 # Cổ phiếu sàn HSX
# ---> 12 hsx_stocks = ref.equity.list_by_exchange("HSX")
#      14 # Cổ phiếu theo ngành ICB
#      15 industry_stocks = ref.equity.list_by_industry()
#
# TypeError: EquityReference.list_by_exchange() takes 1 positional argument but 2 were given
